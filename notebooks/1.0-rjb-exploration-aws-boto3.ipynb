# %% [markdown]
# ## [Boto 3 Documentation](https://boto3.amazonaws.com/v1/documentation/api/1.9.42/index.html)
#
# Boto is the Amazon Web Services (AWS) SDK for Python, which allows Python developers to write software that makes use of Amazon services like S3 and EC2. Boto provides an easy to use, object-oriented API as well as low-level direct service access

# %%
import boto3
import botocore

# %%
s3 = boto3.resource('s3')  # tell boto to use Amazon s3

# %% [markdown]
# Now that you have an s3 resource, you can make requests and process responses from the service. The following uses the buckets collection to print out all bucket names:

# %%
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# auswheatdata

# %% [markdown]
# ## Downloading a File
# The example below tries to download an S3 object to a file. If the service returns a 404 error, it prints an error message indicating that the object doesn't exist.

# %%
BUCKET_NAME = 'auswheatdata' # replace with your bucket name
KEY = 'weather_data/wa_silo_weather_data.csv' # replace with your object key

s3 = boto3.resource('s3')

try:
    s3.Bucket(BUCKET_NAME).download_file(KEY, 'my_local_wa_silo_weather_data.csv')
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "404":
        print("The object does not exist.")
    else:
        raise

# %%
for bucket in s3.buckets.all():
    for key in bucket.objects.all():
        print(key.key)
# Out:
# census data/
# wa_silo_weather_data.csv
# weather_data/
# weather_data/wa_silo_weather_data.csv

# %%
s3client = boto3.client('s3', region_name='us-east-1')

# %%
objects = s3client.list_objects(Bucket='noaa-ghcn-pds')

# %%
print(objects)
# Out:
# {'ResponseMetadata': {'RequestId': '1BF2897607EBF2A6', 'HostId': 'Gq+QIJfOJX9ehrqa3OnrQjuGGn7Nh8VLu6VragwLFn6WSMRaow1Uhe2TJIimS61Blxe0APkaqx4=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'Gq+QIJfOJX9ehrqa3OnrQjuGGn7Nh8VLu6VragwLFn6WSMRaow1Uhe2TJIimS61Blxe0APkaqx4=', 'x-amz-request-id': '1BF2897607EBF2A6', 'date': 'Thu, 01 Aug 2019 09:41:02 GMT', 'x-amz-bucket-region': 'us-east-1', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'IsTruncated': False, 'Marker': '', 'Contents': [{'Key': 'by-year-status.txt', 'LastModified': datetime.datetime(2018, 12, 21, 12, 46, 33, tzinfo=tzutc()), 'ETag': '"c105251a4f3deb24d3f91009b0bb4135"', 'Size': 936, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1763.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 37, tzinfo=tzutc()), 'ETag': '"efe18d88cfb5c3372fe0206c521b2239"', 'Size': 3358, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1764.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 38, tzinfo=tzutc()), 'ETag': '"76680ee7de2fcc0ab1f75ce57f68a1a8"', 'Size': 3327, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1765.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 39, tzinfo=tzutc()), 'ETag': '"fc0039c49ad60b272154aaa3e1f33028"', 'Size': 3335, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1766.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 39, tzinfo=tzutc()), 'ETag': '"fab2c4904fcfb1243ded857fdde8d467"', 'Size': 3344, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1767.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 40, tzinfo=tzutc()), 'ETag': '"657a45fcd51d39059799c3ec93f353ce"', 'Size': 3356, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1768.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 40, tzinfo=tzutc()), 'ETag': '"e6d4edf1653d8c3e8d1fdcc360e99e3f"', 'Size': 3325, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1769.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 41, tzinfo=tzutc()), 'ETag': '"65a787ba3a69d762dc3a4012e00b9389"', 'Size': 3418, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1770.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 41, tzinfo=tzutc()), 'ETag': '"8f9e80f7e42cc9c63e555fccadd2579a"', 'Size': 3357, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1771.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 42, tzinfo=tzutc()), 'ETag': '"eb0384b96b58929d70db37075224ea25"', 'Size': 3373, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1772.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 42, tzinfo=tzutc()), 'ETag': '"485c8493830d4edb35610f3c87f96477"', 'Size': 3419, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1773.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 43, tzinfo=tzutc()), 'ETag': '"d5a62e3465b71a8be5a7060c263ed4d3"', 'Size': 3368, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1774.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 43, tzinfo=tzutc()), 'ETag': '"4068fc56f144604c3276ca049921d623"', 'Size': 3393, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1775.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 44, tzinfo=tzutc()), 'ETag': '"271f0b81d803107f19921814135ca336"', 'Size': 6365, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1776.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 45, tzinfo=tzutc()), 'ETag': '"984f2a2dd02a8d39827f2ba7abd9e69d"', 'Size': 6425, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1777.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 46, tzinfo=tzutc()), 'ETag': '"319ac732e08bdb858b3e7d8f3e7994d5"', 'Size': 6424, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1778.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 47, tzinfo=tzutc()), 'ETag': '"43919fff2bbbde0d02c50d78978d0b25"', 'Size': 6255, 'StorageClass': 'STANDARD'}, {'Key': 'csv.gz/1779.csv.gz', 'LastModified': datetime.datetime(2019, 7, 31, 23, 38, 47, tzinfo=tzutc()), 'ETag': '"13cb7f133348a0 ...

# %% [markdown]
# ## Upload a File to an Amazon S3 Bucket
# The example below shows how to:
# * Upload a file to a bucket using upload_file.

# %%
# Create an S3 client
s3 = boto3.client('s3')

filename = r'C:\Users\rj71b\geo-projects\wheatbelt_rainfall_analyser\data\raw\wa_silo_weather_data.csv'
bucket_name = 'auswheatdata'

# Uploads the given file using a managed uploader, which will split up large
# files automatically and upload parts in parallel.
s3.upload_file(filename, bucket_name, 'wa_silo_weather_data.csv')

# %%
s3 = boto3.resource('s3')

# %%
s3.Bucket('auswheatdata').upload_file(r'C:\Users\rj71b\geo-projects\wheatbelt_rainfall_analyser\data\raw\wa_silo_july_data.csv','%s/%s' %('weather_data','wa_silo_july_data.csv'))

# %%
s3.put_object(
   Bucket=bucket_name, 
   Key='weatherdata/wa_silo_weather_data.csv', 
   Body=filename
)
# Out:
# {'ResponseMetadata': {'RequestId': '2707B5DAE4A037B8',
#   'HostId': 'w9fDZrIkwLmw2wCm+iMtWtMETSJt1QUQAKXBtz/69+TBsiuPr7dkTonrqKdJbC0FBy+sNLfrhF8=',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amz-id-2': 'w9fDZrIkwLmw2wCm+iMtWtMETSJt1QUQAKXBtz/69+TBsiuPr7dkTonrqKdJbC0FBy+sNLfrhF8=',
#    'x-amz-request-id': '2707B5DAE4A037B8',
#    'date': 'Fri, 02 Aug 2019 06:06:04 GMT',
#    'etag': '"3eb427e23171d38d0273ff2cfe1fd410"',
#    'content-length': '0',
#    'server': 'AmazonS3'},
#   'RetryAttempts': 0},
#  'ETag': '"3eb427e23171d38d0273ff2cfe1fd410"'}

# %%
s3 = boto3.client('s3')
