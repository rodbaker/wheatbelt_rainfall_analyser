# %% [markdown]
# ## [Boto 3 Documentation](https://boto3.amazonaws.com/v1/documentation/api/1.9.42/index.html)
#
# Boto is the Amazon Web Services (AWS) SDK for Python, which allows Python developers to write software that makes use of Amazon services like S3 and EC2. Boto provides an easy to use, object-oriented API as well as low-level direct service access

# %%
import boto3
import botocore

# %%
s3 = boto3.resource('s3')  # tell boto to use Amazon s3

# %% [markdown]
# Now that you have an s3 resource, you can make requests and process responses from the service. The following uses the buckets collection to print out all bucket names:

# %%
# Print out bucket names
for bucket in s3.buckets.all():
    print(bucket.name)
# Out:
# auswheatdata

# %% [markdown]
# ## Downloading a File
# The example below tries to download an S3 object to a file. If the service returns a 404 error, it prints an error message indicating that the object doesn't exist.

# %%
BUCKET_NAME = 'auswheatdata' # replace with your bucket name
KEY = 'weather_data/wa_silo_weather_data.csv' # replace with your object key

s3 = boto3.resource('s3')

try:
    s3.Bucket(BUCKET_NAME).download_file(KEY, 'my_local_wa_silo_weather_data.csv')
except botocore.exceptions.ClientError as e:
    if e.response['Error']['Code'] == "404":
        print("The object does not exist.")
    else:
        raise

# %%
for bucket in s3.buckets.all():
    for key in bucket.objects.all():
        print(key.key)
# Out:
# census data/
# weather_data/
# weather_data/wa_silo_july_data.csv
# weather_data/wa_silo_weather_data.csv

# %%
s3client = boto3.client('s3', region_name='us-east-1')

# %%
objects = s3client.list_objects(Bucket='noaa-ghcn-pds')

# %%
print(objects)
# Out:
# {'ResponseMetadata': {'RequestId': 'KXX9QGF6J0BH6PGR', 'HostId': 'mLO6K3bkHe/tyQQ7k9UnovHnaz5YmN6A0tJYhTjNR2ElwyMNuO/5NZuQz34dDw8we9zi9dnJRww=', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amz-id-2': 'mLO6K3bkHe/tyQQ7k9UnovHnaz5YmN6A0tJYhTjNR2ElwyMNuO/5NZuQz34dDw8we9zi9dnJRww=', 'x-amz-request-id': 'KXX9QGF6J0BH6PGR', 'date': 'Mon, 27 Jan 2025 11:21:49 GMT', 'x-amz-bucket-region': 'us-east-1', 'content-type': 'application/xml', 'transfer-encoding': 'chunked', 'server': 'AmazonS3'}, 'RetryAttempts': 0}, 'IsTruncated': True, 'Marker': '', 'Contents': [{'Key': 'csv.gz/1763.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 24, tzinfo=tzutc()), 'ETag': '"efe18d88cfb5c3372fe0206c521b2239"', 'Size': 3358, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1764.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 6, tzinfo=tzutc()), 'ETag': '"76680ee7de2fcc0ab1f75ce57f68a1a8"', 'Size': 3327, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1765.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 18, tzinfo=tzutc()), 'ETag': '"fc0039c49ad60b272154aaa3e1f33028"', 'Size': 3335, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1766.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 6, tzinfo=tzutc()), 'ETag': '"fab2c4904fcfb1243ded857fdde8d467"', 'Size': 3344, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1767.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 6, tzinfo=tzutc()), 'ETag': '"657a45fcd51d39059799c3ec93f353ce"', 'Size': 3356, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1768.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 24, tzinfo=tzutc()), 'ETag': '"e6d4edf1653d8c3e8d1fdcc360e99e3f"', 'Size': 3325, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1769.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 6, tzinfo=tzutc()), 'ETag': '"65a787ba3a69d762dc3a4012e00b9389"', 'Size': 3418, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1770.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 24, tzinfo=tzutc()), 'ETag': '"8f9e80f7e42cc9c63e555fccadd2579a"', 'Size': 3357, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1771.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 25, tzinfo=tzutc()), 'ETag': '"eb0384b96b58929d70db37075224ea25"', 'Size': 3373, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1772.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 25, tzinfo=tzutc()), 'ETag': '"485c8493830d4edb35610f3c87f96477"', 'Size': 3419, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1773.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 25, tzinfo=tzutc()), 'ETag': '"d5a62e3465b71a8be5a7060c263ed4d3"', 'Size': 3368, 'StorageClass': 'STANDARD', 'Owner': {'DisplayName': 'sandbox', 'ID': '07cd0b2bd0f30623096b9275946be8ed8f210ec3ec83f15b416f8296c4e7e947'}}, {'Key': 'csv.gz/1774.csv.gz', 'LastModified': datetime.datetime(2022, 9, 9, 18, 5, 18, tzinfo=tzutc()), 'ETag': '"4068 ...

# %% [markdown]
# ## Upload a File to an Amazon S3 Bucket
# The example below shows how to:
# * Upload a file to a bucket using upload_file.

# %%
# Create an S3 client
s3 = boto3.client('s3')

filename = r'/mnt/c/Users/rj71b/Desktop/2025-01-19_Viterra_stocks.csv'
bucket_name = 'auswheatdata'

# Uploads the given file using a managed uploader, which will split up large
# files automatically and upload parts in parallel.
s3.upload_file(filename, bucket_name, 'Viterra_test_data.csv')

# %%
import boto3

# Initialize the S3 client
s3_client = boto3.client('s3')

# Define bucket name and file details
bucket_name = 'auswheatdata'
file_path = '/mnt/c/Users/rj71b/Desktop/2025-01-19_Viterra_stocks.csv'  # Update the path to the correct location
s3_key = 'weatherdata/wa_silo_weather_data.csv'

# Upload the file
with open(file_path, 'rb') as file_data:
    s3_client.put_object(Bucket=bucket_name, Key=s3_key, Body=file_data)

print(f"File uploaded successfully to {bucket_name}/{s3_key}")
# Out:
# File uploaded successfully to auswheatdata/weatherdata/wa_silo_weather_data.csv
